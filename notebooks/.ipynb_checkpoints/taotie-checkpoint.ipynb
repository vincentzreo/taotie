# %%
import pandas as pd

# %%
df = pd.read_parquet('../assets/sample2.parquet')

# %%
df.head()
# Out:
#                              email                                     name  \
# 0   b'rickie.6cl60vv5@example.net'  b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'
# 1     b'olaf.14ymhjtf@example.org'  b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'
# 2  b'rebecca.3a623w6u@example.com'  b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'
# 3   b'yvonne.qx06kzs6@example.org'  b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'
# 4   b'juston.apls64ti@example.org'  b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'
#
#        gender                       created_at  \
# 0  b'unknown' 2020-08-10 13:01:25.925310+00:00
# 1  b'unknown' 2021-11-13 13:00:25.903489+00:00
# 2  b'unknown' 2020-03-27 01:20:25.909394+00:00
# 3  b'unknown' 2022-07-04 00:23:25.871170+00:00
# 4  b'unknown' 2023-11-15 00:40:25.923932+00:00
#
#                    last_visited_at                  last_watched_at  \
# 0 2024-05-04 09:50:25.925310+00:00 2024-04-16 14:54:25.925310+00:00
# 1 2024-04-25 20:57:25.903489+00:00 2024-02-14 23:31:25.903489+00:00
# ...

# %%
df.describe()
# Out:
#                                  email  \
# count                             1000
# unique                            1000
# top     b'rickie.6cl60vv5@example.net'
# freq                                 1
# mean                               NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#                                            name      gender  \
# count                                      1000        1000
# unique                                      986           1
# top     b'\xe8\xb4\xba\xe6\xad\x86\xe7\xbf\xa0'  b'unknown'
# freq                                          2        1000
# mean                                        NaN         NaN
# min                                         NaN         NaN
# 25%                                         NaN         NaN
# ...

# %%
df[df['created_at'] >= '2024-02-01']
# Out:
#                                 email  \
# 240  b'theresia.qffrdky6@example.net'
# 630     b'vesta.ogpio1y5@example.org'
#
#                                         name      gender  \
# 240  b'\xe5\xb4\x94\xe5\xbd\xac\xe9\x94\x90'  b'unknown'
# 630  b'\xe4\xbb\x98\xe9\xbe\x99\xe5\xbe\xb7'  b'unknown'
#
#                           created_at                  last_visited_at  \
# 240 2024-02-05 03:50:25.903207+00:00 2024-04-28 09:32:25.903207+00:00
# 630 2024-02-01 04:42:25.891426+00:00 2024-04-23 14:30:25.891426+00:00
#
#                      last_watched_at  \
# 240 2024-03-09 13:20:25.903207+00:00
# 630 2024-02-17 12:09:25.891426+00:00
#
#                                         recent_watched  \
# 240  [111996, 137611, 115212, 122468, 101856, 12805...
# 630  [145438, 156496, 114852, 121073, 190656, 18604...
#
#                                 viewed_but_not_started  \
# 240  [221404, 220027, 220353, 257174, 241009, 22829...
# 630  [201621, 276264, 244972, 256725, 229254, 26239...
# ...

# %%
df['created_at'].count()
# Out:
# np.int64(1000)
